# %%
#Compute the Most Popular Start Hour
#Use pandas to load chicago.csv into a dataframe, and find the most frequent hour when people start traveling.
#There isn't an hour column in this dataset, 
#but you can create one by extracting the hour from the "Start Time" column.
#To do this, you can convert "Start Time" to the datetime datatype using the pandas to_datetime()

#https://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html

  #method and extracting properties such as the hour with these properties.
#- https://pandas.pydata.org/pandas-docs/stable/api.html#datetimelike-properties

#Hint: Another way to describe the most common value in a column is the mode.

import pandas as pd

filename = 'chicago.csv'

# load data file into a dataframe
df = pd.read_csv(filename)

df.head()
# Out:
#             Start Time             End Time  Trip Duration  \
# 0  2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1  2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2  2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3  2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4  2017-01-26 15:36:07  2017-01-26 15:43:21            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year
# 0  Subscriber    Male      1991.0
# 1    Customer     NaN         NaN
# 2  Subscriber  Female      1982.0
# 3  Subscriber    Male      1966.0
# ...

# %%
import datetime as dt

# %%
# convert the Start Time column to datetime
df['Start Time'] = pd.to_datetime(df['Start Time'], yearfirst= True, errors='raise')

# %%
df['Weekday'] = df['Start Time'].dt.day_name
df['Weekday']
# Out:
# 0      <bound method PandasDelegate._add_delegate_acc...
# 1      <bound method PandasDelegate._add_delegate_acc...
# 2      <bound method PandasDelegate._add_delegate_acc...
# 3      <bound method PandasDelegate._add_delegate_acc...
# 4      <bound method PandasDelegate._add_delegate_acc...
#                              ...
# 395    <bound method PandasDelegate._add_delegate_acc...
# 396    <bound method PandasDelegate._add_delegate_acc...
# 397    <bound method PandasDelegate._add_delegate_acc...
# 398    <bound method PandasDelegate._add_delegate_acc...
# 399    <bound method PandasDelegate._add_delegate_acc...
# Name: Weekday, Length: 400, dtype: object

# %%
df['Month'] = df['Start Time'].dt.month

df['Month']
# Out:
# 0      5
# 1      6
# 2      2
# 3      4
# 4      1
#       ..
# 395    2
# 396    5
# 397    6
# 398    5
# 399    5
# Name: Month, Length: 400, dtype: int64

# %%
df.head()
# Out:
#            Start Time             End Time  Trip Duration  \
# 0 2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1 2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2 2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3 2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4 2017-01-26 15:36:07  2017-01-26 15:43:21            434
#
#                   Start Station                          End Station  \
# 0     Columbus Dr & Randolph St                 Federal St & Polk St
# 1        Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# 2         Canal St & Madison St              Paulina Ave & North Ave
# 3  Spaulding Ave & Armitage Ave       California Ave & Milwaukee Ave
# 4        Clark St & Randolph St         Financial Pl & Congress Pkwy
#
#     User Type  Gender  Birth Year  \
# 0  Subscriber    Male      1991.0
# 1    Customer     NaN         NaN
# 2  Subscriber  Female      1982.0
# 3  Subscriber    Male      1966.0
# ...

# %%
df['year'] = pd.DatetimeIndex(df['Start Time']).year

# %%
df
# Out:
#              Start Time             End Time  Trip Duration  \
# 0   2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1   2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2   2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3   2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4   2017-01-26 15:36:07  2017-01-26 15:43:21            434
# ..                  ...                  ...            ...
# 395 2017-02-06 13:34:32  2017-02-06 13:41:35            423
# 396 2017-05-22 16:44:08  2017-05-22 16:48:05            237
# 397 2017-06-09 17:03:44  2017-06-09 17:24:30           1246
# 398 2017-05-16 08:14:27  2017-05-16 08:28:24            837
# 399 2017-05-16 12:48:34  2017-05-16 12:58:17            583
#
#                     Start Station                          End Station  \
# 0       Columbus Dr & Randolph St                 Federal St & Polk St
# 1          Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# ...

# %%
df['week'] = df['Start Time'].dt.week

df['week']
# Out:
# 0      22
# 1      24
# 2       7
# 3      17
# 4       4
#        ..
# 395     6
# 396    21
# 397    23
# 398    20
# 399    20
# Name: week, Length: 400, dtype: int64

# %%
df['weekday'] = df['Start Time'].dt.weekday

df['weekday']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      3
#       ..
# 395    0
# 396    0
# 397    4
# 398    1
# 399    1
# Name: weekday, Length: 400, dtype: int64

# %%
df = df.drop("Weekday", 1)

# %%
df
# Out:
#              Start Time             End Time  Trip Duration  \
# 0   2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1   2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2   2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3   2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4   2017-01-26 15:36:07  2017-01-26 15:43:21            434
# ..                  ...                  ...            ...
# 395 2017-02-06 13:34:32  2017-02-06 13:41:35            423
# 396 2017-05-22 16:44:08  2017-05-22 16:48:05            237
# 397 2017-06-09 17:03:44  2017-06-09 17:24:30           1246
# 398 2017-05-16 08:14:27  2017-05-16 08:28:24            837
# 399 2017-05-16 12:48:34  2017-05-16 12:58:17            583
#
#                     Start Station                          End Station  \
# 0       Columbus Dr & Randolph St                 Federal St & Polk St
# 1          Kingsbury St & Erie St  Orleans St & Merchandise Mart Plaza
# ...

# %%
df["weekday"].value_counts()
# Out:
# 1    64
# 0    62
# 4    59
# 6    58
# 2    55
# 3    53
# 5    49
# Name: weekday, dtype: int64

# %%
# extract hour from the Start Time column to create an hour column
df['hour'] = df['Start Time'].dt.hour

df['hour']
# Out:
# 0      18
# 1      19
# 2      17
# 3      18
# 4      15
#        ..
# 395    13
# 396    16
# 397    17
# 398     8
# 399    12
# Name: hour, Length: 400, dtype: int64

# %%
df["hour"].value_counts()
# Out:
# 17    53
# 18    36
# 12    31
# 16    29
# 13    26
# 19    26
# 15    25
# 7     23
# 8     22
# 14    21
# 9     20
# 11    19
# 10    16
# 6     14
# 20    11
# 21    11
# 22     7
# 23     4
# 0      4
# 5      2
# Name: hour, dtype: int64

# %%
len(df["hour"].value_counts())
# Out:
# 20

# %%
import statistics as st

# %%
from collections import Counter

# %%
c = Counter(df["hour"])

# %%
c
# Out:
# Counter({18: 36,
#          19: 26,
#          17: 53,
#          15: 25,
#          9: 20,
#          8: 22,
#          7: 23,
#          12: 31,
#          6: 14,
#          13: 26,
#          23: 4,
#          11: 19,
#          21: 11,
#          14: 21,
#          16: 29,
#          22: 7,
#          20: 11,
#          10: 16,
#          0: 4,
#          5: 2})

# %%
# find the most common hour (from 0 to 23)
popular_hour = c.most_common(1)
print('Most Frequent Start Hour:', popular_hour)
# Out:
# Most Frequent Start Hour: [(17, 53)]
